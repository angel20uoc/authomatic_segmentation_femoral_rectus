# %%
import tensorflow as tf
print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.10.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("✓ Memoria GPU configurada correctamente")
    except RuntimeError as e:
        print(e)
# Out:
# ✓ Memoria GPU configurada correctamente

# %%
from tensorflow.keras import layers, models
import tensorflow.keras.backend as K

# %%
#1. Cargar los splits generados en Notebook 04
import pandas as pd

train_df = pd.read_csv("train_split.csv")
val_df   = pd.read_csv("val_split.csv")
test_df  = pd.read_csv("test_split.csv")

len(train_df), len(val_df), len(test_df)
# Out:
# (319, 57, 67)

# %%
#2. Función para convertir el DataFrame → tf.data.Dataset

TARGET_SIZE = (384, 384)

def load_image(path):
    img = tf.io.read_file(path)
    img = tf.io.decode_jpeg(img, channels=1)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, TARGET_SIZE)
    return img

def load_mask(path):
    mask = tf.io.read_file(path)
    mask = tf.io.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, TARGET_SIZE)
    mask = tf.where(mask > 0, 1.0, 0.0)
    return mask

def load_pair(img_path, mask_path):
    img = load_image(img_path)
    mask = load_mask(mask_path)
    return img, mask

def df_to_dataset(df, shuffle=True):
    img_paths = df["img"].values
    mask_paths = df["mask"].values

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    ds = ds.map(lambda x, y: load_pair(x, y), num_parallel_calls=tf.data.AUTOTUNE)

    if shuffle:
        ds = ds.shuffle(512)

    return ds

# %%
#3. Crear los datasets finales

BATCH_SIZE = 4

train_ds = df_to_dataset(train_df)
train_ds = train_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_ds = df_to_dataset(val_df, shuffle=False)
val_ds = val_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

test_ds = df_to_dataset(test_df, shuffle=False)
test_ds = test_ds.batch(BATCH_SIZE)

# %%
#4. Métricas y funciones de pérdida (Dice + BCE)

def dice_coef(y_true, y_pred, smooth=1e-6):
    #Dice Coefficient
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_loss(y_true, y_pred):
    #Dice loss
    return 1 - dice_coef(y_true, y_pred)

def bce_dice_loss(y_true, y_pred):
    #Binary Cross-Entropy + Dice Loss
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    dsc = dice_loss(y_true, y_pred)
    return bce + dsc

# %%
#5. Bloques de la U-Net

def conv_block(x, filters):
    #Bloque conv (Conv → BN → ReLU → Conv → BN → ReLU)
    x = layers.Conv2D(filters, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(filters, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    return x

def up_block(x, skip, filters):
    #Bloque de upsampling
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Concatenate()([x, skip])
    x = conv_block(x, filters)
    return x

# %%
#6. Arquitectura U-Net (384×384×1)
def build_unet(input_shape=(384, 384, 1), filters=32):
    inputs = layers.Input(input_shape)

    # Encoder
    c1 = conv_block(inputs, filters);       p1 = layers.MaxPool2D()(c1)
    c2 = conv_block(p1, filters*2);         p2 = layers.MaxPool2D()(c2)
    c3 = conv_block(p2, filters*4);         p3 = layers.MaxPool2D()(c3)
    c4 = conv_block(p3, filters*8);         p4 = layers.MaxPool2D()(c4)

    # Bottleneck
    bn = conv_block(p4, filters*16)

    # Decoder
    u1 = up_block(bn, c4, filters*8)
    u2 = up_block(u1, c3, filters*4)
    u3 = up_block(u2, c2, filters*2)
    u4 = up_block(u3, c1, filters)

    # Output
    outputs = layers.Conv2D(1, 1, activation="sigmoid")(u4)

    return models.Model(inputs, outputs)

# %%
#7. Construir el modelo
model = build_unet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 384, 384, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 384, 384, 32  320         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 384, 384, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 384, 384, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 384, 384, 32  9248        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 384, 384, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 384, 384, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 192, 192, 32  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 192, 192, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 192, 192, 64  256        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 192, 192, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 192, 192, 64  36928       ['activation_2[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 192, 192, 64  256        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 192, 192, 64  0           ['batch_normalization_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 96, 96, 64)  0           ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 96, 96, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 96, 96, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 96, 96, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 96, 96, 128)  147584      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 96, 96, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 96, 96, 128)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 48, 48, 128)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 48, 48, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 48, 48, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 48, 48, 256)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 48, 48, 256)  590080      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 48, 48, 256)  1024       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 48, 48, 256)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 24, 24, 256)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 24, 24, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 24, 24, 512)  2048       ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 24, 24, 512)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 24, 24, 512)  2359808     ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 24, 24, 512)  2048       ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 24, 24, 512)  0           ['batch_normalization_9[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 48, 48, 512)  0           ['activation_9[0][0]']
#
#  concatenate (Concatenate)      (None, 48, 48, 768)  0           ['up_sampling2d[0][0]',
#                                                                   'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 48, 48, 256)  1769728     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 48, 48, 256)  1024       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 48, 48, 256)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 48, 48, 256)  590080      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 48, 48, 256)  1024       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 48, 48, 256)  0           ['batch_normalization_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 96, 96, 256)  0          ['activation_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 96, 96, 384)  0           ['up_sampling2d_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 96, 96, 128)  442496      ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 96, 96, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 96, 96, 128)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 96, 96, 128)  147584      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 96, 96, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 96, 96, 128)  0           ['batch_normalization_13[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 192, 192, 12  0          ['activation_13[0][0]']
#                                 8)
#
#  concatenate_2 (Concatenate)    (None, 192, 192, 19  0           ['up_sampling2d_2[0][0]',
#                                 2)                                'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 192, 192, 64  110656      ['concatenate_2[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 192, 192, 64  256        ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  activation_14 (Activation)     (None, 192, 192, 64  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 192, 192, 64  36928       ['activation_14[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 192, 192, 64  256        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 192, 192, 64  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  up_sampling2d_3 (UpSampling2D)  (None, 384, 384, 64  0          ['activation_15[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 384, 384, 96  0           ['up_sampling2d_3[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 384, 384, 32  27680       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 384, 384, 32  128        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 384, 384, 32  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 384, 384, 32  9248        ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 384, 384, 32  128        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 384, 384, 32  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 384, 384, 1)  33          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 7,857,857
# Trainable params: 7,851,969
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
#8. Compilación
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=bce_dice_loss,
    metrics=["accuracy", dice_coef]
)

# %%
#9. Callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        patience=10, monitor="val_loss", restore_best_weights=True
    ),
    tf.keras.callbacks.ModelCheckpoint(
        "unet_best_model.h5", monitor="val_loss", save_best_only=True
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.3, patience=4, min_lr=1e-7
    ),
    tf.keras.callbacks.TensorBoard(log_dir="logs")
]

# %%
#10. Entrenamiento
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=60,
    callbacks=callbacks
)
# Out:
# Epoch 1/60
# 80/80 [==============================] - 290s 264ms/step - loss: 0.8273 - accuracy: 0.8935 - dice_coef: 0.4915 - val_loss: 1.3154 - val_accuracy: 0.8697 - val_dice_coef: 0.1884 - lr: 1.0000e-04
# Epoch 2/60
# 80/80 [==============================] - 19s 235ms/step - loss: 0.5408 - accuracy: 0.9522 - dice_coef: 0.6428 - val_loss: 1.2693 - val_accuracy: 0.8697 - val_dice_coef: 0.1522 - lr: 1.0000e-04
# Epoch 3/60
# 80/80 [==============================] - 19s 233ms/step - loss: 0.4521 - accuracy: 0.9637 - dice_coef: 0.6958 - val_loss: 1.3140 - val_accuracy: 0.8697 - val_dice_coef: 0.0940 - lr: 1.0000e-04
# Epoch 4/60
# 80/80 [==============================] - 19s 233ms/step - loss: 0.4025 - accuracy: 0.9687 - dice_coef: 0.7278 - val_loss: 1.3403 - val_accuracy: 0.8697 - val_dice_coef: 0.0823 - lr: 1.0000e-04
# Epoch 5/60
# 80/80 [==============================] - 19s 231ms/step - loss: 0.3594 - accuracy: 0.9732 - dice_coef: 0.7549 - val_loss: 1.3052 - val_accuracy: 0.8710 - val_dice_coef: 0.1014 - lr: 1.0000e-04
# Epoch 6/60
# 80/80 [==============================] - 19s 233ms/step - loss: 0.3351 - accuracy: 0.9744 - dice_coef: 0.7714 - val_loss: 1.2202 - val_accuracy: 0.8798 - val_dice_coef: 0.1931 - lr: 1.0000e-04
# Epoch 7/60
# 80/80 [==============================] - 19s 236ms/step - loss: 0.2837 - accuracy: 0.9805 - dice_coef: 0.8048 - val_loss: 0.6424 - val_accuracy: 0.9355 - val_dice_coef: 0.5811 - lr: 1.0000e-04
# Epoch 8/60
# 80/80 [==============================] - 19s 234ms/step - loss: 0.2583 - accuracy: 0.9823 - dice_coef: 0.8208 - val_loss: 0.4689 - val_accuracy: 0.9453 - val_dice_coef: 0.7148 - lr: 1.0000e-04
# Epoch 9/60
# 80/80 [==============================] - 19s 231ms/step - loss: 0.2345 - accuracy: 0.9839 - dice_coef: 0.8369 - val_loss: 0.9200 - val_accuracy: 0.9048 - val_dice_coef: 0.3985 - lr: 1.0000e-04
# Epoch 10/60
# 80/80 [==============================] - 19s 236ms/step - loss: 0.2231 - accuracy: 0.9838 - dice_coef: 0.8455 - val_loss: 0.4661 - val_accuracy: 0.9459 - val_dice_coef: 0.7504 - lr: 1.0000e-04
# Epoch 11/60
# 80/80 [==============================] - 19s 233ms/step - loss: 0.1961 - accuracy: 0.9864 - dice_coef: 0.8625 - val_loss: 0.4200 - val_accuracy: 0.9563 - val_dice_coef: 0.7382 - lr: 1.0000e-04
# Epoch 12/60
# 80/80 [==============================] - 19s 233ms/step - loss: 0.1747 - accuracy: 0.9882 - dice_coef: 0.8771 - val_loss: 0.3826 - val_accuracy: 0.9573 - val_dice_coef: 0.7681 - lr: 1.0000e-04
# Epoch 13/60
# 80/80 [==============================] - 19s 234ms/step - loss: 0.1535 - accuracy: 0.9900 - dice_coef: 0.8912 - val_loss: 0.3392 - val_accuracy: 0.9647 - val_dice_coef: 0.7983 - lr: 1.0000e-04
# Epoch 14/60
# 80/80 [==============================] - 19s 233ms/step - loss: 0.1390 - accuracy: 0.9912 - dice_coef: 0.9012 - val_loss: 0.3097 - val_accuracy: 0.9666 - val_dice_coef: 0.8185 - lr: 1.0000e-04
# Epoch 15/60
# 80/80 [==============================] - 19s 231ms/step - loss: 0.1271 - accuracy: 0.9918 - dice_coef: 0.9095 - val_loss: 0.3581 - val_accuracy: 0.9612 - val_dice_coef: 0.7905 - lr: 1.0000e-04
# Epoch 16/60
# 80/80 [==============================] - 19s 230ms/step - loss: 0.1174 - accuracy: 0.9923 - dice_coef: 0.9168 - val_loss: 0.5296 - val_accuracy: 0.9323 - val_dice_coef: 0.7581 - lr: 1.0000e-04
# Epoch 17/60
# 80/80 [==============================] - 19s 231ms/step - loss: 0.1123 - accuracy: 0.9924 - dice_coef: 0.9207 - val_loss: 0.3140 - val_accuracy: 0.9654 - val_dice_coef: 0.8289 - lr: 1.0000e-04
# Epoch 18/60
# 80/80 [==============================] - 19s 236ms/step - loss: 0.0980 - accuracy: 0.9936 - dice_coef: 0.9303 - val_loss: 0.3091 - val_accuracy: 0.9664 - val_dice_coef: 0.8331 - lr: 1.0000e-04
# Epoch 19/60
# 80/80 [==============================] - 19s 231ms/step - loss: 0.0901 - accuracy: 0.9941 - dice_coef: 0.9358 - val_loss: 0.3286 - val_accuracy: 0.9643 - val_dice_coef: 0.8224 - lr: 1.0000e-04
# Epoch 20/60
# 80/80 [==============================] - 19s 232ms/step - loss: 0.0854 - accuracy: 0.9942 - dice_coef: 0.9395 - val_loss: 0.3519 - val_accuracy: 0.9613 - val_dice_coef: 0.8083 - lr: 1.0000e-04
# Epoch 21/60
# 80/80 [==============================] - 19s 232ms/step - loss: 0.0783 - accuracy: 0.9947 - dice_coef: 0.9443 - val_loss: 0.4167 - val_accuracy: 0.9546 - val_dice_coef: 0.7778 - lr: 1.0000e-04
# Epoch 22/60
# 80/80 [==============================] - 19s 232ms/step - loss: 0.0747 - accuracy: 0.9948 - dice_coef: 0.9472 - val_loss: 0.3123 - val_accuracy: 0.9653 - val_dice_coef: 0.8507 - lr: 1.0000e-04
# Epoch 23/60
# 80/80 [==============================] - 19s 237ms/step - loss: 0.0659 - accuracy: 0.9959 - dice_coef: 0.9525 - val_loss: 0.3015 - val_accuracy: 0.9670 - val_dice_coef: 0.8488 - lr: 3.0000e-05
# Epoch 24/60
# 80/80 [==============================] - 19s 231ms/step - loss: 0.0605 - accuracy: 0.9966 - dice_coef: 0.9559 - val_loss: 0.3102 - val_accuracy: 0.9662 - val_dice_coef: 0.8444 - lr: 3.0000e-05
# Epoch 25/60
# 80/80 [==============================] - 19s 235ms/step - loss: 0.0569 - accuracy: 0.9969 - dice_coef: 0.9584 - val_loss: 0.2992 - val_accuracy: 0.9677 - val_dice_coef: 0.8535 - lr: 3.0000e-05
# Epoch 26/60
# 80/80 [==============================] - 19s 232ms/step - loss: 0.0558 - accuracy: 0.9971 - dice_coef: 0.9590 - val_loss: 0.3187 - val_accuracy: 0.9655 - val_dice_coef: 0.8449 - lr: 3.0000e-05
# Epoch 27/60
# 80/80 [==============================] - 19s 236ms/step - loss: 0.0536 - accuracy: 0.9973 - dice_coef: 0.9605 - val_loss: 0.3057 - val_accuracy: 0.9671 - val_dice_coef: 0.8521 - lr: 3.0000e-05
# Epoch 28/60
# 80/80 [==============================] - 19s 234ms/step - loss: 0.0515 - accuracy: 0.9974 - dice_coef: 0.9622 - val_loss: 0.3097 - val_accuracy: 0.9667 - val_dice_coef: 0.8537 - lr: 3.0000e-05
# Epoch 29/60
# 80/80 [==============================] - 19s 234ms/step - loss: 0.0508 - accuracy: 0.9974 - dice_coef: 0.9627 - val_loss: 0.3169 - val_accuracy: 0.9661 - val_dice_coef: 0.8495 - lr: 3.0000e-05
# Epoch 30/60
# 80/80 [==============================] - 19s 234ms/step - loss: 0.0484 - accuracy: 0.9977 - dice_coef: 0.9643 - val_loss: 0.3068 - val_accuracy: 0.9672 - val_dice_coef: 0.8559 - lr: 9.0000e-06
# Epoch 31/60
# 80/80 [==============================] - 19s 234ms/step - loss: 0.0469 - accuracy: 0.9979 - dice_coef: 0.9653 - val_loss: 0.3058 - val_accuracy: 0.9674 - val_dice_coef: 0.8563 - lr: 9.0000e-06
# Epoch 32/60
# 80/80 [==============================] - 19s 233ms/step - loss: 0.0464 - accuracy: 0.9980 - dice_coef: 0.9654 - val_loss: 0.3065 - val_accuracy: 0.9674 - val_dice_coef: 0.8575 - lr: 9.0000e-06
# Epoch 33/60
# 80/80 [==============================] - 19s 231ms/step - loss: 0.0466 - accuracy: 0.9980 - dice_coef: 0.9652 - val_loss: 0.3186 - val_accuracy: 0.9663 - val_dice_coef: 0.8507 - lr: 9.0000e-06
# Epoch 34/60
# 80/80 [==============================] - 19s 232ms/step - loss: 0.0451 - accuracy: 0.9981 - dice_coef: 0.9664 - val_loss: 0.3121 - val_accuracy: 0.9670 - val_dice_coef: 0.8555 - lr: 2.7000e-06
# Epoch 35/60
# 80/80 [==============================] - 19s 233ms/step - loss: 0.0445 - accuracy: 0.9982 - dice_coef: 0.9668 - val_loss: 0.3106 - val_accuracy: 0.9673 - val_dice_coef: 0.8565 - lr: 2.7000e-06

# %%
#11. Guardar el modelo final
model.save("unet_final_model.h5")

# %%
#12. Gráfica de métricas

import matplotlib.pyplot as plt

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.history["loss"], label="loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.title("Loss U-Net++")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history["dice_coef"], label="dice")
plt.plot(history.history["val_dice_coef"], label="val_dice")
plt.title("Dice U-Net++")
plt.legend()

plt.show()
